# %% [markdown]
# ## ***Importing Libraries***

# %%
import pandas as pd              # Data manipulation and analysis
import numpy as np               # Numerical computations and arrays
import matplotlib.pyplot as plt  # Basic plotting and visualization
import seaborn as sns            # Statistical data visualization library
import plotly.express as px      # Interactive plotting high-level API
import plotly.graph_objects as go # Detailed interactive plot control
import warnings                  # Manage and control warning messages

warnings.filterwarnings("ignore") # Ignore unnecessary warning messages
# Display plots inside notebook
# %matplotlib inline

# %% [markdown]
# ## ***Importing Data***

# %%
data=pd.read_csv('/content/drive/MyDrive/guvi/Traffic_Violations.csv')

# %%
df = data.copy(deep=True)  # Create independent dataframe copy

# %%
pd.set_option('display.max_columns', None)  # Show all dataframe columns
df.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  52282e8c-f2e1-4bb5-8509-2d5e4f8da8ca   05/01/2023     23:11:00    MCP
# 1  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
# 2  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
# 3  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
# 4  b66f253b-af29-4bc4-bb73-93755ca2a779   08/31/2023     16:41:00    MCP
#
#                                          SubAgency  \
# 0                      3rd District, Silver Spring
# 1  6th District, Gaithersburg / Montgomery Village
# 2  6th District, Gaithersburg / Montgomery Village
# 3  6th District, Gaithersburg / Montgomery Village
# 4  6th District, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0    OPERATING UNREGISTERED MOTOR VEHICLE ON HIGHWAY
# 1  DRIVING TO DRIVE MOTOR VEHICLE ON HIGHWAY WITH...
# 2  FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 3  DRIVER OF MOTOR VEHICLE FOLLOWING VEHICLE CLOS...
# 4  FAILURE TO CONTROL VEH. SPEED ON HWY. TO AVOID...
#
#                            Location   Latitude  Longitude Accident Belts  \
# 0  BRIGGS CHANEY RD @ COLUMIBA PIKE   0.000000    0.00000       No    No
# 1       OAKMONT AVE @ GROVEMONT CIR  39.097965  -77.15301       No    No
# 2       OAKMONT AVE @ GROVEMONT CIR  39.097965  -77.15301       No    No
# 3       OAKMONT AVE @ GROVEMONT CIR  39.097965  -77.15301       No    No
# 4       OAKMONT AVE @ GROVEMONT CIR  39.097965  -77.15301       No    No
#
#   Personal Injury Property Damage Fatal Commercial License HAZMAT  \
# 0              No              No    No                 No     No
# 1              No              No    No                 No     No
# 2              No              No    No                 No     No
# 3              No              No    No                 No     No
# 4              No              No    No                 No     No
#
#   Commercial Vehicle Alcohol Work Zone Search Conducted Search Disposition  \
# 0                 No      No        No               No                NaN
# 1                 No      No        No               No                NaN
# 2                 No      No        No               No                NaN
# 3                 No      No        No               No                NaN
# 4                 No      No        No               No                NaN
#
#   Search Outcome Search Reason Search Reason For Stop Search Type  \
# 0       Citation           NaN             17-107(a1)         NaN
# 1       Citation           NaN             20-102(a1)         NaN
# 2       Citation           NaN             20-102(a1)         NaN
# 3       Citation           NaN             20-102(a1)         NaN
# 4       Citation           NaN             20-102(a1)         NaN
#
#   Search Arrest Reason State      VehicleType    Year  Make     Model  Color  \
# 0                  NaN    MD  02 - Automobile  2007.0  CHEV      CRUZ  BLACK
# 1                  NaN    MD  02 - Automobile  2005.0  FORD  EXPLORER  BLACK
# 2                  NaN    MD  02 - Automobile  2005.0  FORD  EXPLORER  BLACK
# 3                  NaN    MD  02 - Automobile  2005.0  FORD  EXPLORER  BLACK
# 4                  NaN    MD  02 - Automobile  2005.0  FORD  EXPLORER  BLACK
#
#   Violation Type      Charge                 Article  Contributed To Accident  \
# 0       Citation  13-401(b1)  Transportation Article                    False
# 1       Citation  16-101(a1)  Transportation Article                    False
# 2       Citation   13-409(b)  Transportation Article                    False
# 3       Citation   21-310(a)  Transportation Article                    False
# 4       Citation   21-801(b)  Transportation Article                    False
#
#        Race Gender   Driver City Driver State DL State        Arrest Type  \
# 0     WHITE      M  GAITHERSBURG           MD       MD  A - Marked Patrol
# 1  HISPANIC      M  GAITHERSBURG           MD       MD  A - Marked Patrol
# 2  HISPANIC      M  GAITHERSBURG           MD       MD  A - Marked Patrol
# 3  HISPANIC      M  GAITHERSBURG           MD       MD  A - Marked Patrol
# 4  HISPANIC      M  GAITHERSBURG           MD       MD  A - Marked Patrol
#
#               Geolocation
# 0              (0.0, 0.0)
# 1  (39.097965, -77.15301)
# 2  (39.097965, -77.15301)
# 3  (39.097965, -77.15301)
# 4  (39.097965, -77.15301)

# %%
df.shape
# Out:
# (2070115, 43)

# %% [markdown]
# ***Insight***
#
# **2070115** rows and **43** columns

# %%
df.info()  # Display dataframe structure summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2070115 entries, 0 to 2070114
# Data columns (total 43 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   SeqID                    object
#  1   Date Of Stop             object
#  2   Time Of Stop             object
#  3   Agency                   object
#  4   SubAgency                object
#  5   Description              object
#  6   Location                 object
#  7   Latitude                 float64
#  8   Longitude                float64
#  9   Accident                 object
#  10  Belts                    object
#  11  Personal Injury          object
#  12  Property Damage          object
#  13  Fatal                    object
#  14  Commercial License       object
#  15  HAZMAT                   object
#  16  Commercial Vehicle       object
#  17  Alcohol                  object
#  18  Work Zone                object
#  19  Search Conducted         object
#  20  Search Disposition       object
#  21  Search Outcome           object
#  22  Search Reason            object
#  23  Search Reason For Stop   object
#  24  Search Type              object
#  25  Search Arrest Reason     object
#  26  State                    object
#  27  VehicleType              object
#  28  Year                     float64
#  29  Make                     object
#  30  Model                    object
#  31  Color                    object
#  32  Violation Type           object
#  33  Charge                   object
#  34  Article                  object
#  35  Contributed To Accident  bool
#  36  Race                     object
#  37  Gender                   object
#  38  Driver City              object
#  39  Driver State             object
#  40  DL State                 object
#  41  Arrest Type              object
#  42  Geolocation              object
# dtypes: bool(1), float64(3), object(39)
# memory usage: 665.3+ MB

# %% [markdown]
# ## ***Checking Null Values***

# %%
df.isnull().sum()[df.isnull().sum() != 0]
# Out:
# Description                    10
# Location                        4
# Search Conducted           786125
# Search Disposition        1980574
# Search Outcome             805416
# Search Reason             1980574
# Search Reason For Stop     786428
# Search Type               1980582
# Search Arrest Reason      2008149
# State                          59
# Year                        10645
# Make                           74
# Model                         223
# Color                       22300
# Article                     92680
# Driver City                   519
# Driver State                   11
# DL State                      929
# dtype: int64

# %% [markdown]
# ## ***Memory Usage***

# %%
df.memory_usage(deep=True)
# Out:
# Index                            132
# SeqID                      175959775
# Date Of Stop               122136785
# Time Of Stop               117996555
# Agency                     107645980
# SubAgency                  157924112
# Description                227478707
# Location                   155120932
# Latitude                    16560920
# Longitude                   16560920
# Accident                   105632548
# Belts                      105640232
# Personal Injury            105601051
# Property Damage            105621248
# Fatal                      105576433
# Commercial License         105633743
# HAZMAT                     105576018
# Commercial Vehicle         105582491
# Alcohol                    105578487
# Work Zone                  105576313
# Search Conducted            90729031
# Search Disposition          68872212
# Search Outcome              96950104
# Search Reason               69149039
# Search Reason For Stop      99603549
# Search Type                 68192692
# Search Arrest Reason        67585021
# State                      105574744
# VehicleType                133187012
# Year                        16560920
# Make                       111827940
# Model                      111295385
# Color                      111375633
# Violation Type             116627098
# Charge                     120033002
# Article                    143202377
# Contributed To Accident      2070115
# Race                       113215244
# Gender                     103505750
# Driver City                123678537
# Driver State               105575656
# DL State                   105558214
# Arrest Type                137453212
# Geolocation                164629983
# dtype: int64

# %% [markdown]
# ### ***Statistical Analysis***

# %%
df.describe(include='number')
# Out:
#            Latitude     Longitude          Year
# count  2.070115e+06  2.070115e+06  2.059470e+06
# mean   3.613803e+01 -7.130162e+01  2.007615e+03
# std    1.032062e+01  2.036307e+01  8.489762e+01
# min    0.000000e+00 -1.512560e+02  0.000000e+00
# 25%    3.901642e+01 -7.719294e+01  2.003000e+03
# 50%    3.906618e+01 -7.708753e+01  2.008000e+03
# 75%    3.913717e+01 -7.702696e+01  2.013000e+03
# max    4.154316e+01  3.906444e+01  9.999000e+03

# %%
df.describe(include='object').T
# Out:
#                           count   unique  \
# SeqID                   2070115  1178080
# Date Of Stop            2070115     5086
# Time Of Stop            2070115     1440
# Agency                  2070115        1
# SubAgency               2070115        9
# Description             2070105    17806
# Location                2070111   269352
# Accident                2070115        2
# Belts                   2070115        2
# Personal Injury         2070115        2
# Property Damage         2070115        2
# Fatal                   2070115        2
# Commercial License      2070115        2
# HAZMAT                  2070115        2
# Commercial Vehicle      2070115        2
# Alcohol                 2070115        2
# Work Zone               2070115        2
# Search Conducted        1283990        2
# Search Disposition        89541        7
# Search Outcome          1264699        5
# Search Reason             89541       10
# Search Reason For Stop  1283687      842
# Search Type               89533        6
# Search Arrest Reason      61966       11
# State                   2070056       72
# VehicleType             2070115       36
# Make                    2070041     4935
# Model                   2069892    23386
# Color                   2047815       26
# Violation Type          2070115        4
# Charge                  2070115     1199
# Article                 1977435        6
# Race                    2070115        6
# Gender                  2070115        3
# Driver City             2069596     9374
# Driver State            2070104       68
# DL State                2069186       72
# Arrest Type             2070115       19
# Geolocation             2070115  1026161
#
#                                                                       top  \
# SeqID                                33c49de3-9e36-4f36-9326-b59a95e86fe8
# Date Of Stop                                                   03/17/2015
# Time Of Stop                                                     23:30:00
# Agency                                                                MCP
# SubAgency                                           4th District, Wheaton
# Description             DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# Location                             MONTGOMERY VILLAGE AVE @ RUSSELL AVE
# Accident                                                               No
# Belts                                                                  No
# Personal Injury                                                        No
# Property Damage                                                        No
# Fatal                                                                  No
# Commercial License                                                     No
# HAZMAT                                                                 No
# Commercial Vehicle                                                     No
# Alcohol                                                                No
# Work Zone                                                              No
# Search Conducted                                                       No
# Search Disposition                                                Nothing
# Search Outcome                                                    Warning
# Search Reason                                          Incident to Arrest
# Search Reason For Stop                                         21-201(a1)
# Search Type                                                          Both
# Search Arrest Reason                                                 Stop
# State                                                                  MD
# VehicleType                                               02 - Automobile
# Make                                                               TOYOTA
# Model                                                                  4S
# Color                                                               BLACK
# Violation Type                                                    Warning
# Charge                                                           21-801.1
# Article                                            Transportation Article
# Race                                                                WHITE
# Gender                                                                  M
# Driver City                                                 SILVER SPRING
# Driver State                                                           MD
# DL State                                                               MD
# Arrest Type                                             A - Marked Patrol
# Geolocation                                                    (0.0, 0.0)
#
#                            freq
# SeqID                        59
# Date Of Stop               1281
# Time Of Stop               3000
# Agency                  2070115
# SubAgency                449193
# Description              171401
# Location                   2451
# Accident                2013432
# Belts                   2005748
# Personal Injury         2044929
# Property Damage         2024732
# Fatal                   2069547
# Commercial License      2012237
# HAZMAT                  2069962
# Commercial Vehicle      2063489
# Alcohol                 2067493
# Work Zone               2069667
# Search Conducted        1194449
# Search Disposition        38864
# Search Outcome           638761
# Search Reason             51802
# Search Reason For Stop   154351
# Search Type               67096
# Search Arrest Reason      40071
# State                   1797987
# VehicleType             1835701
# Make                     240535
# Model                    199699
# Color                    437199
# Violation Type          1090515
# Charge                   286707
# Article                 1957419
# Race                     691032
# Gender                  1393963
# Driver City              503076
# Driver State            1871813
# DL State                1805484
# Arrest Type             1657617
# Geolocation              156092

# %% [markdown]
# ## ***Categorical Columns***

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['SeqID', 'Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency',
#        'Description', 'Location', 'Accident', 'Belts', 'Personal Injury',
#        'Property Damage', 'Fatal', 'Commercial License', 'HAZMAT',
#        'Commercial Vehicle', 'Alcohol', 'Work Zone', 'Search Conducted',
#        'Search Disposition', 'Search Outcome', 'Search Reason',
#        'Search Reason For Stop', 'Search Type', 'Search Arrest Reason',
#        'State', 'VehicleType', 'Make', 'Model', 'Color', 'Violation Type',
#        'Charge', 'Article', 'Race', 'Gender', 'Driver City', 'Driver State',
#        'DL State', 'Arrest Type', 'Geolocation'],
#       dtype='object')

# %% [markdown]
# ## ***Numerical Columns***

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Latitude', 'Longitude', 'Year'], dtype='object')

# %% [markdown]
# # ***Data Preprocessing***

# %% [markdown]
# **Duplicate values**

# %%
df.duplicated().sum()  #Count duplicates
# Out:
# np.int64(2354)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ***Insights***
#
# Keeps the first occurrence
#
# Removes exact row duplicates

# %% [markdown]
# **Handling Missing Values**

# %%
df.isnull().sum()[df.isnull().sum() != 0]
# Out:
# Description                    10
# Location                        4
# Search Conducted           785295
# Search Disposition        1978521
# Search Outcome             804561
# Search Reason             1978521
# Search Reason For Stop     785598
# Search Type               1978528
# Search Arrest Reason      2006050
# State                          59
# Year                        10615
# Make                           74
# Model                         223
# Color                       22265
# Article                     92674
# Driver City                   514
# Driver State                   11
# DL State                      929
# dtype: int64

# %%
# search related columns
search_cols = [
    'Search Conducted',
    'Search Disposition',
    'Search Outcome',
    'Search Reason',
    'Search Reason For Stop',
    'Search Type',
    'Search Arrest Reason'
]

df[search_cols] = df[search_cols].fillna('Not Applicable')
 # Replace missing search values

# %%
df['Location'].fillna('unknown',inplace=True)
df['Description'].fillna('Not Recorded',inplace=True)
df['Color'].fillna('Unknown', inplace=True)
df['Article'].fillna('Not Recorded', inplace=True)

# %%
df['State'].fillna(df['State'].mode()[0],inplace=True)
df['Make'].fillna(df['Make'].mode()[0],inplace=True)
df['Model'].fillna(df['Model'].mode()[0],inplace=True)
df['Driver City'].fillna(df['Driver City'].mode()[0],inplace=True)
df['DL State'].fillna(df['DL State'].mode()[0],inplace=True)
df['Driver State'].fillna(df['Driver State'].mode()[0],inplace=True)
#Less missing values so i replaced it with mode

# %% [markdown]
# ## ***Feature Engineering***

# %% [markdown]
# ### ***SeqID***

# %%
df['SeqID'].describe()
# Out:
# count                                  2067761
# unique                                 1178080
# top       33c49de3-9e36-4f36-9326-b59a95e86fe8
# freq                                        59
# Name: SeqID, dtype: object

# %%
df['SeqID'].nunique()
# Out:
# 1178080

# %%
df["SeqID"] = df["SeqID"].astype(str)
# SeqID as an ID, not a number

# %% [markdown]
# ### ***Date Of Stop***

# %%
df['Date Of Stop'].unique()
# Out:
# array(['05/01/2023', '08/31/2023', '04/30/2023', ..., '11/30/2025',
#        '12/04/2025', '12/05/2025'], dtype=object)

# %%
# Convert column into datetime format
df["Date Of Stop"] = pd.to_datetime(df["Date Of Stop"], errors="coerce")


# Check unrealistic year mistakes
df.loc[df["Date Of Stop"].dt.year > 2025, "Date Of Stop"] = pd.NaT

# %%
df["Date Of Stop"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### ***Time Of Stop***

# %%
df['Time Of Stop'] = (
    df['Time Of Stop']
    .astype(str)                      # Convert values to string
    .str.replace('.', ':', regex=False)  # Replace dots with colons
)

# Convert to proper time format
df['Time Of Stop'] = pd.to_datetime(
    df['Time Of Stop'],
    format='%H:%M:%S',
    errors='coerce'
)

# %%
# Extract hour of stop
df['Stop Hour'] = df['Time Of Stop'].dt.hour

# %%
df['Stop Hour']
# Out:
# 0          23
# 1          16
# 2          16
# 3          16
# 4          16
#            ..
# 2070110    13
# 2070111    15
# 2070112    21
# 2070113     7
# 2070114    13
# Name: Stop Hour, Length: 2067761, dtype: int32

# %%
df['Stop Timestamp'] = df['Date Of Stop'] + \
                       pd.to_timedelta(df['Time Of Stop'].dt.strftime('%H:%M:%S'))

# %% [markdown]
# ### ***Agency***

# %%
df["Agency"] = df["Agency"].str.upper().str.strip()

# %%
df.Agency.value_counts()
# Out:
# Agency
# MCP    2067761
# Name: count, dtype: int64

# %%
df['Agency'].describe()
# Out:
# count     2067761
# unique          1
# top           MCP
# freq      2067761
# Name: Agency, dtype: object

# %% [markdown]
# ### ***SubAgency***

# %%
# Extract numeric district values from SubAgency
df['District Number'] = (
    df['SubAgency']
    .str.extract(r'(\d+)')      # Extract numeric digits from text
    .astype('Int64')            # Convert to nullable integer type
)

# %% [markdown]
# **.str.extract(r'(\d+)')**
#
# Uses regular expression
#
# \d+ → one or more digits
#
# Extracts the first number found in the string

# %%
df['District Number']
# Out:
# 0          3
# 1          6
# 2          6
# 3          6
# 4          6
#           ..
# 2070110    2
# 2070111    4
# 2070112    3
# 2070113    1
# 2070114    5
# Name: District Number, Length: 2067761, dtype: Int64

# %% [markdown]
# ### ***Location***

# %%
df.Location
# Out:
# 0           BRIGGS CHANEY RD @ COLUMIBA PIKE
# 1                OAKMONT AVE @ GROVEMONT CIR
# 2                OAKMONT AVE @ GROVEMONT CIR
# 3                OAKMONT AVE @ GROVEMONT CIR
# 4                OAKMONT AVE @ GROVEMONT CIR
#                          ...
# 2070110                 RAMSEY AVE/WAYNE AVE
# 2070111               GEORGIA AVE/ARCOLA AVE
# 2070112    E RANDOLPH ROAD/OLD COLUMBIA PIKE
# 2070113        GAINSBOROUGH RD @ HOB NAIL CT
# 2070114       WOODFIELD DR @ FLOWER HILL WAY
# Name: Location, Length: 2067761, dtype: object

# %%
df['Location'] = (
    df['Location']
    .astype(str)                     # Ensure string type
    .str.replace('@', '/', regex=False)  # Replace @ with /
)

# %%
 #Extract primary road name
df['Primary Road'] = (
    df['Location']
    .str.split('/')                  # Split intersection locations
    .str[0]                          # Keep main road name
    .str.strip()                     # Remove leading/trailing spaces
)

# %%
df['Primary Road']
# Out:
# 0          BRIGGS CHANEY RD
# 1               OAKMONT AVE
# 2               OAKMONT AVE
# 3               OAKMONT AVE
# 4               OAKMONT AVE
#                  ...
# 2070110          RAMSEY AVE
# 2070111         GEORGIA AVE
# 2070112     E RANDOLPH ROAD
# 2070113     GAINSBOROUGH RD
# 2070114        WOODFIELD DR
# Name: Primary Road, Length: 2067761, dtype: object

# %%
cols = ['SubAgency', 'Description', 'Location','Search Reason','Model']

df[cols] = df[cols].apply(
    lambda x: x.astype(str).str.strip().str.lower()
)

# %% [markdown]
# ### ***Latitude and Longitude***

# %%
df['Latitude']
# Out:
# 0           0.000000
# 1          39.097965
# 2          39.097965
# 3          39.097965
# 4          39.097965
#              ...
# 2070110    38.993932
# 2070111     0.000000
# 2070112     0.000000
# 2070113    39.034735
# 2070114    39.156796
# Name: Latitude, Length: 2067761, dtype: float64

# %%
df.loc[(df['Latitude'] < -90) | (df['Latitude'] > 90),'Latitude']=np.nan
# Replace invalid latitude with NaN

# %%
df.loc[(df['Longitude'] < -125) | (df['Longitude'] > -65),'Longitude'] = np.nan
# Replace invalid longitude with NaN

# %% [markdown]
# ### ***Boolean Columns***

# %%
bool_cols = [
    "Accident",
    "Belts",
    "Personal Injury",
    "Property Damage",
    "Fatal",
    "Commercial License",
    "HAZMAT",
    "Commercial Vehicle",
    "Alcohol",
    "Work Zone"]

for col in bool_cols:
    print(f"\nValue counts for {col}")
    print(df[col].value_counts(dropna=False))
# Out:
# Value counts for Accident
# Accident
# No     2011283
# Yes      56478
# Name: count, dtype: int64
#
# Value counts for Belts
# Belts
# No     2003455
# Yes      64306
# Name: count, dtype: int64
#
# Value counts for Personal Injury
# Personal Injury
# No     2042652
# Yes      25109
# Name: count, dtype: int64
#
# Value counts for Property Damage
# Property Damage
# No     2022620
# Yes      45141
# Name: count, dtype: int64
#
# Value counts for Fatal
# Fatal
# No     2067194
# Yes        567
# Name: count, dtype: int64
#
# Value counts for Commercial License
# Commercial License
# No     2009984
# Yes      57777
# Name: count, dtype: int64
#
# Value counts for HAZMAT
# HAZMAT
# No     2067608
# Yes        153
# Name: count, dtype: int64
#
# Value counts for Commercial Vehicle
# Commercial Vehicle
# No     2061155
# Yes       6606
# Name: count, dtype: int64
#
# Value counts for Alcohol
# Alcohol
# No     2065146
# Yes       2615
# Name: count, dtype: int64
#
# Value counts for Work Zone
# Work Zone
# No     2067313
# Yes        448
# Name: count, dtype: int64

# %%
df[bool_cols] = df[bool_cols].replace({'Yes': True, 'No': False})

# %%
df[bool_cols].dtypes
# Out:
# Accident              bool
# Belts                 bool
# Personal Injury       bool
# Property Damage       bool
# Fatal                 bool
# Commercial License    bool
# HAZMAT                bool
# Commercial Vehicle    bool
# Alcohol               bool
# Work Zone             bool
# dtype: object

# %% [markdown]
# ### ***State***

# %%
df.State.unique()
# Out:
# array(['MD', 'XX', 'VA', 'NY', 'DC', 'WI', 'NC', 'GA', 'MN', 'OH', 'PA',
#        'IL', 'KY', 'TX', 'NM', 'FL', 'DE', 'AR', 'WY', 'NJ', 'WV', 'OR',
#        'TN', 'CA', 'IA', 'UT', 'IN', 'AZ', 'MO', 'MA', 'LA', 'MS', 'ND',
#        'SC', 'ME', 'US', 'NV', 'MI', 'PE', 'RI', 'AL', 'WA', 'AK', 'OK',
#        'CT', 'ON', 'KS', 'NB', 'NH', 'MT', 'VT', 'CO', 'VI', 'SD', 'ID',
#        'NU', 'HI', 'QC', 'NE', 'MB', 'AB', 'PR', 'PQ', 'NF', 'NS', 'MH',
#        'BC', 'AS', 'GU', 'IT', 'YT', 'SK'], dtype=object)

# %%
df['State']=df['State'].str.upper()

# %% [markdown]
# ### ***VehicleType***

# %%
df['VehicleType'].unique()
# Out:
# array(['02 - Automobile', '19 - Moped', '05 - Light Duty Truck',
#        '07 - Truck/Road Tractor', '01 - Motorcycle',
#        '20 - Commercial Rig', '28 - Other', '12 - School Bus',
#        '03 - Station Wagon', '25 - Utility Trailer',
#        '06 - Heavy Duty Truck', '08 - Recreational Vehicle',
#        '29 - Unknown', '04 - Limousine', '10 - Transit Bus',
#        '27 - Farm Equipment', '11 - Cross Country Bus',
#        '21 - Tandem Trailer', '16 - Fire(Non-Emerg)', '09 - Farm Vehicle',
#        '18 - Police Vehicle', '23 - Travel/Home Trailer',
#        '15 - Fire(Emerg)', '14 - Ambulance(Non-Emerg)',
#        '13 - Ambulance(Emerg)', '26 - Boat Trailer',
#        '18 - Police(Non-Emerg)', '22 - Mobile Home', '24 - Camper',
#        '13 - Ambulance', '15 - Fire Vehicle', '14 - Ambulance',
#        '17 - Police(Emerg)', '30 - Unknown', '28 - Electric Bicycle',
#        '29 - Other'], dtype=object)

# %%
df['VehicleType'] = (
    df['VehicleType']
    .astype(str)                           # Convert values to string
    .str.replace(r'\s*-\s*', ' - ', regex=True)  # Normalize hyphen spacing
    .str.strip()                           # Remove leading/trailing spaces
)

# %% [markdown]
# ####****str.replace(r'\s*-\s*', ' - ', regex=True)**
#
# Regex breakdown:
#
# \s* → zero or more spaces
#
# - → hyphen
#
# \s* → zero or more spaces

# %%
# Extract numeric vehicle type code
df['VehicleType_Code'] = (
    df['VehicleType']
    .str.extract(r'^(\d+)')     # Extract starting numeric digits
    .astype('Int64')            # Convert to nullable integer
)

# %% [markdown]
# ### ***str.extract(r'^(\d+)')***
#
#
# Regex breakdown:
#
# ^ → start of the string
#
# \d+ → one or more digits

# %%
df['VehicleType_Code'].unique()
# Out:
# <IntegerArray>
# [ 2, 19,  5,  7,  1, 20, 28, 12,  3, 25,  6,  8, 29,  4, 10, 27, 11, 21, 16,
#   9, 18, 23, 15, 14, 13, 26, 22, 24, 17, 30]
# Length: 30, dtype: Int64

# %%
df['VehicleType_Category'] = (
    df['VehicleType']
    .str.replace(r'^\d+\s*-\s*', '', regex=True)  # Remove leading numeric code
    .str.strip()                                 # Remove extra spaces
    .str.lower()                                 # Convert text to lowercase
)

# %% [markdown]
# ####****str.replace(r'^\d+\s*-\s*', '', regex=True)**
#
# r'^\d+\s*-\s*' (the regex)
#
# ^ → start of the string
#
# \d+ → one or more digits (vehicle code)
#
# \s* → optional spaces
#
# - → literal hyphen
#
# \s* → optional spaces

# %%
df['VehicleType_Category'].unique()
# Out:
# array(['automobile', 'moped', 'light duty truck', 'truck/road tractor',
#        'motorcycle', 'commercial rig', 'other', 'school bus',
#        'station wagon', 'utility trailer', 'heavy duty truck',
#        'recreational vehicle', 'unknown', 'limousine', 'transit bus',
#        'farm equipment', 'cross country bus', 'tandem trailer',
#        'fire(non - emerg)', 'farm vehicle', 'police vehicle',
#        'travel/home trailer', 'fire(emerg)', 'ambulance(non - emerg)',
#        'ambulance(emerg)', 'boat trailer', 'police(non - emerg)',
#        'mobile home', 'camper', 'ambulance', 'fire vehicle',
#        'police(emerg)', 'electric bicycle'], dtype=object)

# %% [markdown]
# ### ***Year***

# %%
df.Year
# Out:
# 0          2007.0
# 1          2005.0
# 2          2005.0
# 3          2005.0
# 4          2005.0
#             ...
# 2070110    2011.0
# 2070111    2020.0
# 2070112    2010.0
# 2070113    2019.0
# 2070114    2019.0
# Name: Year, Length: 2067761, dtype: float64

# %%
df['Year'] = df['Year'].astype('Int64')

# %%
# Identify unrealistic vehicle years
invalid_years = df.loc[(df['Year'] < 1950) | (df['Year'] > 2026),'Year'].unique()

# %%
# Replace invalid years with missing
df.loc[(df['Year'] < 1950) | (df['Year'] > 2026),'Year'] = pd.NA

# %% [markdown]
# ### ***Color***

# %%
df.Color.value_counts()
# Out:
# Color
# BLACK          436741
# SILVER         365410
# WHITE          341530
# GRAY           252862
# RED            157087
# BLUE           150538
# GREEN           62565
# GOLD            56015
# BLUE, DARK      44000
# TAN             35616
# MAROON          34111
# BLUE, LIGHT     24715
# Unknown         22265
# BEIGE           20267
# GREEN, DK       18659
# GREEN, LGT      10155
# BROWN            8731
# ORANGE           7336
# YELLOW           7231
# BRONZE           4503
# PURPLE           3759
# MULTICOLOR       1560
# CREAM            1115
# COPPER            590
# PINK              315
# CHROME             45
# CAMOUFLAGE         40
# Name: count, dtype: int64

# %%
df['Color'] = df['Color'].astype(str).str.strip().str.lower()

# %%
# Standardize vehicle color categories
df['Color'] = df['Color'].replace({
    'BLUE, DARK': 'BLUE',     # Merge dark blue into blue
    'BLUE, LIGHT': 'BLUE',    # Merge light blue into blue
    'GREEN, DK': 'GREEN',     # Merge dark green into green
    'GREEN, LGT': 'GREEN'     # Merge light green into green
})

# %% [markdown]
# ### ***Violation Type***

# %%
df['Violation Type'].value_counts()
# Out:
# Violation Type
# Warning     1089807
# Citation     885280
# ESERO         91778
# SERO            896
# Name: count, dtype: int64

# %% [markdown]
# ### ***Charge***

# %%
df['Charge'].value_counts()
# Out:
# Charge
# 21-801.1       286697
# 21-201(a1)     171274
# 13-409(b)       91428
# 21-707(a)       65528
# 13-401(h)       61493
#                 ...
# 24-203              1
# 15-312(a)           1
# 13-113.2(d)         1
# 21-509(f)           1
# 14-107(h)           1
# Name: count, Length: 1199, dtype: int64

# %%
df['Charge'] = df['Charge'].astype(str).str.strip().str.upper()

# %%
# Combine multiple charges per traffic stop
charges_per_stop = (
    df.groupby('SeqID')['Charge']                 # Group charges by stop ID
    .apply(lambda x: ', '.join(sorted(set(x))))   # Remove duplicates and join
    .reset_index(name='Charges_List')             # Convert back to dataframe
)

# %%
charges_per_stop
# Out:
#                                         SeqID              Charges_List
# 0        00001e27-8bde-4328-8b33-2d2d9a9ce862                 21-503(C)
# 1        0000395c-bbf9-49e3-ba75-91e2da9e98d7  11-393.95(F), 21-201(A1)
# 2        00006268-72eb-42ff-b6b0-50c21d820e9c                 22-226(A)
# 3        000071c5-c385-4191-9cd7-e854d2054963                21-201(A1)
# 4        000099b1-4dcb-4f94-8aef-71ffb198890b      21-801(A), 21-801(B)
# ...                                       ...                       ...
# 1178075  ffffb408-d39e-4c3e-a573-90328763c50c                 21-707(A)
# 1178076  ffffbf8d-668b-49fd-b51d-fe5e5421ae49                 21-204(D)
# 1178077  ffffde34-c896-4614-a480-73600e8500a1                 13-409(B)
# 1178078  fffff356-9830-4664-a240-3f34341c7efc                  21-801.1
# 1178079  fffff914-df6f-4634-97d3-e2202f3d1f86                  21-801.1
#
# [1178080 rows x 2 columns]

# %% [markdown]
# ### ***Article***

# %%
df['Article'].value_counts()
# Out:
# Article
# Transportation Article    1955103
# Not Recorded                92674
# Maryland Rules              19889
# BR                             61
# TG                             22
# 1A                              9
# 00                              3
# Name: count, dtype: int64

# %%
#standardize text to Title Case
df['Article'] = df['Article'].astype(str).str.strip().str.title()

# %% [markdown]
# ### ***Driver City***

# %%
df['Driver City'].astype('str').str.strip().str.lower()
# Out:
# 0           gaithersburg
# 1           gaithersburg
# 2           gaithersburg
# 3           gaithersburg
# 4           gaithersburg
#                ...
# 2070110           laurel
# 2070111    staten island
# 2070112    silver spring
# 2070113          potomac
# 2070114          pacoima
# Name: Driver City, Length: 2067761, dtype: object

# %% [markdown]
# ### ***DL State***

# %%
df['DL State'].unique()
# Out:
# array(['MD', 'VA', 'FL', 'DC', 'OH', 'LA', 'NC', 'NY', 'XX', 'ME', 'GA',
#        'KY', 'PA', 'CA', 'IL', 'MA', 'TN', 'SC', 'IN', 'WV', 'NJ', 'WA',
#        'TX', 'US', 'IA', 'WI', 'NV', 'CT', 'MI', 'SD', 'MO', 'NM', 'AL',
#        'PE', 'HI', 'RI', 'DE', 'ND', 'CO', 'KS', 'AZ', 'MS', 'AK', 'ON',
#        'NE', 'OK', 'WY', 'OR', 'UT', 'IT', 'NH', 'NB', 'AB', 'PR', 'ID',
#        'AR', 'MN', 'BC', 'MT', 'MB', 'VT', 'QC', 'VI', 'SK', 'MH', 'PQ',
#        'AS', 'NF', 'GU', 'NS', 'YT', 'NU'], dtype=object)

# %%
df['DL State'] = df['DL State'].astype(str).str.strip().str.upper()

# %% [markdown]
# ### ***Arrest Type***

# %%
df['Arrest Type'].value_counts()
# Out:
# Arrest Type
# A - Marked Patrol                         1655405
# Q - Marked Laser                           199196
# B - Unmarked Patrol                         97603
# L - Motorcycle                              20953
# G - Marked Moving Radar (Stationary)        19823
# S - License Plate Recognition               16395
# E - Marked Stationary Radar                 16124
# O - Foot Patrol                             14898
# R - Unmarked Laser                          11159
# M - Marked (Off-Duty)                        5519
# I - Marked Moving Radar (Moving)             4298
# H - Unmarked Moving Radar (Stationary)       2660
# F - Unmarked Stationary Radar                1065
# J - Unmarked Moving Radar (Moving)           1055
# C - Marked VASCAR                             543
# P - Mounted Patrol                            365
# N - Unmarked (Off-Duty)                       326
# D - Unmarked VASCAR                           317
# K - Aircraft Assist                            57
# Name: count, dtype: int64

# %%
df['Arrest Type'] = (df['Arrest Type'].astype(str).str.strip())

# %%
# Extract arrest type code letter
df['Arrest_Type_Code'] = (
    df['Arrest Type']
    .str.extract(r'^([A-Z])')   # Capture first uppercase letter
)

# %% [markdown]
# ***str.extract(r'^([A-Z])')***
#
# ^ → start of string
#
# [A-Z] → one uppercase letter
#
# () → capture group (this is what gets returned)

# %%
# Extract arrest type description text
df['Arrest_Type_Desc'] = (
    df['Arrest Type']
    .str.replace(r'^[A-Z]\s*-\s*', '', regex=True)  # Remove letter code and dash
    .str.lower()                                   # Convert description to lowercase
)

# %% [markdown]
# ****str.replace(r'^[A-Z]\s*-\s*', '', regex=True)***
#
# ^	Start of string
#
# [A-Z]	Single uppercase letter
#
# \s*	Zero or more spaces
#
# -	Dash separator
#
# \s*	Optional spaces after dash

# %%
df.Geolocation
# Out:
# 0                               (0.0, 0.0)
# 1                   (39.097965, -77.15301)
# 2                   (39.097965, -77.15301)
# 3                   (39.097965, -77.15301)
# 4                   (39.097965, -77.15301)
#                         ...
# 2070110    (38.9939315, -77.0278283333333)
# 2070111                         (0.0, 0.0)
# 2070112                         (0.0, 0.0)
# 2070113     (39.034735, -77.1740816666667)
# 2070114    (39.1567958333333, -77.1638485)
# Name: Geolocation, Length: 2067761, dtype: object

# %%
# Extract latitude and longitude from Geolocation
geo = df['Geolocation'].astype(str).str.extract(
    r'\(?\s*([-+]?\d*\.?\d+)\s*,\s*([-+]?\d*\.?\d+)\s*\)?'
)

# Convert latitude to numeric
df['Geo_Lat'] = pd.to_numeric(geo[0], errors='coerce')


# Convert longitude to numeric
df['Geo_Lon'] = pd.to_numeric(geo[1], errors='coerce')

# %% [markdown]
# \(?	Optional opening bracket
#
# [-+]?	Optional plus or minus sign
#
# \d*\.?\d+	Decimal number
#
# \s*,\s*	Comma with optional spaces
#
# \)?	Optional closing bracket

# %%
df.loc[
    (df['Geo_Lat'] == 0) & (df['Geo_Lon'] == 0),
    ['Geo_Lat', 'Geo_Lon']
] = pd.NA

# %%
df[['Latitude', 'Geo_Lat']].corr()
df[['Longitude', 'Geo_Lon']].corr()
# Out:
#            Longitude  Geo_Lon
# Longitude        1.0      1.0
# Geo_Lon          1.0      1.0

# %%
df.drop(columns=['Geolocation', 'Geo_Lat', 'Geo_Lon'], inplace=True)

# %%
df.to_parquet('traffic_stops_clean.parquet', index=False)

# %%
df.Gender.value_counts()
# Out:
# Gender
# M    1392231
# F     672009
# U       3521
# Name: count, dtype: int64

# %%
cat_cols = [
    'Agency','SubAgency','State','Make','Model',
    'Color','Violation Type','Race','Gender',
    'VehicleType_Category','Arrest_Type_Desc'
]

for col in cat_cols:
    df[col] = df[col].astype('category')

# %% [markdown]
# ## ***Saving the file***

# %%
from google.colab import files
files.download('traffic_stops_clean.parquet')
